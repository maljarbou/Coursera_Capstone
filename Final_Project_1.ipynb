# %% [markdown]
# # Final Report

# %% [markdown]
# ## Introduction

# %% [markdown]
# Have you ever considered opening a business in **Riyadh, Saudi Arabia**? I bet most of you did and you spent a lot of time thinking about the best location for your business. Well, think no more, with this application, all you have to do is to specify what type of business you are interested in investing in, and it will tell you what neighborhood is best for you. Isn't that great =D

# %% [markdown]
# ## Method and data

# %% [markdown]
# I got a data of all the neighborhoods in Riyadh, and I am planning to iterate on these data get the venues and build a dataframe with all neighborhoods and their top venues. Then based on category of business selected the application will find the neighborhood that is least crowded of that category to suggest it.

# %% [markdown]
# ## Data obtained so far

# %%
import pandas as pd
df = pd.read_excel('Neighboorhood_Riyadh.xlsx', sheet_name='Sheet1')
df
# Out:
#               Neighborhood   Latitude  Longtitude
# 0   Al Uraija Al Gharbiyah  24.594900   46.589152
# 1              Al Aziziyah  24.585913   46.738071
# 2                Umm Salim  24.633751   46.694103
# 3               Al Izdihar  24.780655   46.700005
# 4               Al Badi'ah  24.616217   46.672458
# 5                At Taawun  24.773076   46.681970
# 6               Al Jazirah  24.664702   46.778970
# 7               Al Khuzama  24.715071   46.582610
# 8           As Sulimaniyah  24.698527   46.667436
# 9               As Suwaidi  24.590827   46.661607
# 10              As Sahafah  24.796546   46.602523
# 11                Al Olaya  24.692317   46.648480
# 12                Al Falah  24.797057   46.691701
# 13             Al Mursalat  24.748866   46.672379
# 14                Al Muruj  24.757186   46.644419
# 15               Al Masani  24.552304   46.708993
# 16               Al Maseef  24.765526   46.664032
# 17             Al Maizilah  24.791617   46.802808
# ...
