# %% [markdown]
# # Project - Final Phase

# %% [markdown]
# ## Import needed packages

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
import requests
from pandas.io.json import json_normalize

# %% [markdown]
# ## Load the information from an excel sheet

# %%
riyadh_neighborhoods = pd.read_excel('Neighboorhood_Riyadh.xlsx', sheet_name='Sheet1')
riyadh_neighborhoods
# Out:
#            Neighborhood   Latitude  Longitude
# 0             Umm Salim  24.633751  46.694103
# 1            Al Izdihar  24.780655  46.700005
# 2             At Taawun  24.773076  46.681970
# 3            Al Jazirah  24.664702  46.778970
# 4        As Sulimaniyah  24.698527  46.667436
# 5            As Suwaidi  24.590827  46.661607
# 6            As Sahafah  24.796546  46.602523
# 7              Al Olaya  24.692317  46.648480
# 8              Al Falah  24.797057  46.691701
# 9           Al Mursalat  24.748866  46.672379
# 10             Al Muruj  24.757186  46.644419
# 11            Al Masani  24.552304  46.708993
# 12            Al Maseef  24.765526  46.664032
# 13          Al Maizilah  24.791617  46.802808
# 14         Al Mughrizat  24.764036  46.708234
# 15             Al Malaz  24.664293  46.717901
# 16            King Fahd  24.740652  46.652852
# 17          King Faisal  24.761770  46.757147
# 18            An Nuzhah  24.756436  46.690350
# 19  An Nasim Ash Sharqi  24.738971  46.809932
# 20   An Nasim Al Gharbi  24.725718  46.788947
# 21             An Nazim  24.861030  46.819576
# 22             Al Wahah  24.741184  46.705654
# 23              Al Wadi  24.789519  46.673773
# 24             Al Wurud  24.724320  46.660952
# 25               Shubra  24.574491  46.647010
# 26           Salahuddin  24.732847  46.679460
# 27   Dhahrat Al Badi'ah  24.597210  46.633130
# 28            Ghirnatah  24.795889  46.735990
# 29             Manfuhah  24.599439  46.710986
# 30            Ar Rayyan  24.711396  46.760452
# 31            Ar Rabwah  24.693773  46.736934

# %% [markdown]
# ## Locating the center of Riyadh, Saudi Arabia

# %%
address = 'Riyadh'
geolocator = Nominatim(user_agent="Mohammed-Aljarbou")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Riyadh are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Riyadh are 24.6319692, 46.7150648.

# %% [markdown]
# ## Creating a map cetered at Riyadh with nieghborhoods highlighted

# %%
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)
for lat, lng, neighborhood in zip(riyadh_neighborhoods['Latitude'], riyadh_neighborhoods['Longitude'], riyadh_neighborhoods['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Initilizing my credential for FourSquare

# %%
CLIENT_ID = 'FMBS3BEYLVOH1ZLIJGEA5JUIWE25QYTX5FKMBJCGMH3H05FM' # your Foursquare ID
CLIENT_SECRET = 'OTOLEB5UTIQ55MX0LKUPVNT4W1XMMHXBJGRNMEDC253BQOYJ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FMBS3BEYLVOH1ZLIJGEA5JUIWE25QYTX5FKMBJCGMH3H05FM
# CLIENT_SECRET:OTOLEB5UTIQ55MX0LKUPVNT4W1XMMHXBJGRNMEDC253BQOYJ

# %% [markdown]
# ## A method that will return the venues associated with a given neighborhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1500 , LIMIT = 2000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        results = requests.get(url).json()["response"]['groups'][0]['items']
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ## Requesting venues for each neighborhood

# %%
riyadh_venues = getNearbyVenues(names=riyadh_neighborhoods['Neighborhood'],
                                   latitudes=riyadh_neighborhoods['Latitude'],
                                   longitudes=riyadh_neighborhoods['Longitude']
                                  )

# %%
riyadh_venues.groupby('Neighborhood').count()
# Out:
#                      Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Al Falah                                99                      99     99
# Al Izdihar                             100                     100    100
# Al Jazirah                              33                      33     33
# Al Maizilah                             47                      47     47
# Al Malaz                               100                     100    100
# Al Masani                               52                      52     52
# Al Maseef                              100                     100    100
# Al Mughrizat                           100                     100    100
# Al Mursalat                            100                     100    100
# Al Muruj                                82                      82     82
# Al Olaya                                72                      72     72
# Al Wadi                                100                     100    100
# Al Wahah                                62                      62     62
# Al Wurud                               100                     100    100
# An Nasim Al Gharbi                     100                     100    100
# An Nasim Ash Sharqi                     63                      63     63
# An Nazim                                35                      35     35
# An Nuzhah                              100                     100    100
# Ar Rabwah                              100                     100    100
# Ar Rayyan                               49                      49     49
# As Sahafah                              64                      64     64
# As Sulimaniyah                         100                     100    100
# As Suwaidi                              72                      72     72
# At Taawun                              100                     100    100
# Dhahrat Al Badi'ah                      99                      99     99
# Ghirnatah                               87                      87     87
# King Fahd                              100                     100    100
# King Faisal                             94                      94     94
# Manfuhah                                54                      54     54
# Salahuddin                             100                     100    100
# Shubra                                  76                      76     76
# Umm Salim                               43                      43     43
#
#                      Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Al Falah                         99               99              99
# Al Izdihar                      100              100             100
# Al Jazirah                       33               33              33
# Al Maizilah                      47               47              47
# Al Malaz                        100              100             100
# Al Masani                        52               52              52
# Al Maseef                       100              100             100
# Al Mughrizat                    100              100             100
# Al Mursalat                     100              100             100
# Al Muruj                         82               82              82
# Al Olaya                         72               72              72
# Al Wadi                         100              100             100
# Al Wahah                         62               62              62
# Al Wurud                        100              100             100
# An Nasim Al Gharbi              100              100             100
# An Nasim Ash Sharqi              63               63              63
# An Nazim                         35               35              35
# An Nuzhah                       100              100             100
# Ar Rabwah                       100              100             100
# Ar Rayyan                        49               49              49
# As Sahafah                       64               64              64
# As Sulimaniyah                  100              100             100
# As Suwaidi                       72               72              72
# At Taawun                       100              100             100
# Dhahrat Al Badi'ah               99               99              99
# Ghirnatah                        87               87              87
# King Fahd                       100              100             100
# King Faisal                      94               94              94
# Manfuhah                         54               54              54
# Salahuddin                      100              100             100
# Shubra                           76               76              76
# Umm Salim                        43               43              43

# %%
print('There are {} uniques categories.'.format(len(riyadh_venues['Venue Category'].unique())))
# Out:
# There are 216 uniques categories.

# %% [markdown]
# Cool we got a nice distribution of venues in overall.
# Now let's break the datafram to get a deep look

# %%
riyadh_onehot = pd.get_dummies(riyadh_venues[['Venue Category']], prefix="", prefix_sep="")
riyadh_onehot['Neighborhood'] = riyadh_venues['Neighborhood']
fixed_columns = [riyadh_onehot.columns[-1]] + list(riyadh_onehot.columns[:-1])
riyadh_onehot = riyadh_onehot[fixed_columns]

# %%
matrix = riyadh_onehot.groupby('Neighborhood').sum()

# %%
riyadh_grouped = riyadh_onehot.groupby('Neighborhood').mean().reset_index()
riyadh_grouped
# Out:
#            Neighborhood       ATM  Accessories Store  Afghan Restaurant  \
# 0              Al Falah  0.000000               0.00           0.010101
# 1            Al Izdihar  0.000000               0.00           0.000000
# 18            0.010000         0.000000          0.000000        0.00
# 19            0.020408         0.000000          0.000000        0.00
# 20            0.000000         0.000000          0.000000        0.00
# 21            0.000000         0.000000          0.000000        0.01
# 22            0.013889         0.000000          0.000000        0.00
# 23            0.000000         0.000000          0.000000        0.00
# 24            0.000000         0.000000          0.000000        0.00
# 25            0.000000         0.000000          0.000000        0.00
# 26            0.000000         0.000000          0.010000        0.00
# 27            0.000000         0.000000          0.010638        0.00
# 28            0.037037         0.000000          0.000000        0.00
# 29            0.000000         0.000000          0.010000        0.00
# 30            0.000000         0.000000          0.000000        0.00
# 31            0.000000         0.000000          0.000000        0.00
#
#     Wedding Hall  Wings Joint  Women's Store  Yoga Studio
# 0       0.000000     0.000000           0.00         0.00
# 1       0.000000     0.010000           0.00         0.00
# 2       0.000000     0.000000           0.00         0.00
# 3       0.021277     0.000000           0.00         0.00
# 4       0.000000     0.000000           0.00         0.00
# 5       0.000000     0.000000           0.00         0.00
# 6       0.000000     0.000000           0.00         0.00
# 7       0.000000     0.000000           0.00         0.00
# 8       0.000000     0.000000           0.00         0.00
# 9       0.000000     0.000000           0.00         0.00
# 10      0.000000     0.000000           0.00         0.00
# 11      0.000000     0.000000           0.00         0.00
# 12      0.000000     0.000000           0.00         0.00
# 13      0.000000     0.000000           0.00         0.00
# 14      0.000000     0.000000           0.01         0.00
# 15      0.000000     0.000000           0.00         0.00
# 16      0.000000     0.000000           0.00         0.00
# 17      0.000000     0.000000           0.00         0.00
# 18      0.000000     0.000000           0.00         0.00
# 19      0.000000     0.000000           0.00         0.00
# 20      0.000000     0.000000           0.00         0.00
# 21      0.000000     0.000000           0.00         0.00
# 22      0.000000     0.000000           0.00         0.00
# 23      0.000000     0.000000           0.00         0.00
# 24      0.000000     0.000000           0.00         0.00
# 25      0.000000     0.011494           0.00         0.00
# 26      0.000000     0.000000           0.00         0.01
# 27      0.000000     0.000000           0.00         0.00
# 28      0.000000     0.000000           0.00         0.00
# 29      0.000000     0.000000           0.00         0.00
# 30      0.000000     0.000000           0.00         0.00
# 31      0.000000     0.000000           0.00         0.00
#
# [32 rows x 217 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]
def getBestBusinessNeighborhood(businessname):
    return matrix[businessname].idxmin()

# %% [markdown]
# ## Let's get the top 10 venues for each neighborhood

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = riyadh_grouped['Neighborhood']

for ind in np.arange(riyadh_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(riyadh_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#            Neighborhood      1st Most Common Venue      2nd Most Common Venue  \
# 0              Al Falah                Coffee Shop               Dessert Shop
# 1            Al Izdihar                Coffee Shop                 Donut Shop
# 2            Al Jazirah     Furniture / Home Store       Fast Food Restaurant
# 3           Al Maizilah       Gym / Fitness Center                 Donut Shop
# 4              Al Malaz                Coffee Shop                      Hotel
# 5             Al Masani  Middle Eastern Restaurant                Coffee Shop
# 6             Al Maseef                Coffee Shop               Dessert Shop
# 7          Al Mughrizat                Coffee Shop                     Bakery
# 8           Al Mursalat                Coffee Shop  Middle Eastern Restaurant
# 9              Al Muruj                Coffee Shop                       Café
#
#         5th Most Common Venue      6th Most Common Venue  \
# 0                  Donut Shop               Burger Joint
# 1                  Restaurant             Ice Cream Shop
# 2            Department Store                       Park
# 3                    Pharmacy                  Bookstore
# 4        Fast Food Restaurant  Middle Eastern Restaurant
# 5                 Supermarket                Pizza Place
# 6          Italian Restaurant                Pizza Place
# 7                Burger Joint               Dessert Shop
# 8                 Pizza Place             Cosmetics Shop
# 9                Dessert Shop                 Donut Shop
# 10                Coffee Shop            Thai Restaurant
# 11             Sandwich Place                 Food Truck
# 12                  Juice Bar             Ice Cream Shop
# 13     Furniture / Home Store                 Donut Shop
# 14             Ice Cream Shop                Pizza Place
# 15          Mobile Phone Shop                Auto Garage
# 16                     Palace                       Pool
# 17               Dessert Shop       Fast Food Restaurant
# 18                 Donut Shop                       Café
# 19             Ice Cream Shop               Burger Joint
# 20                Supermarket             Cosmetics Shop
# 21  Middle Eastern Restaurant             Clothing Store
# 22                Pizza Place       Fast Food Restaurant
# 23                 Donut Shop                 Restaurant
# 24               Dessert Shop                       Café
# 25                   Pharmacy               Dessert Shop
# 26              Jewelry Store                     Bakery
# 27                       Café               Dessert Shop
# 28             Cosmetics Shop                Supermarket
# 29     Furniture / Home Store                   Pharmacy
# 30                  Juice Bar                     Bakery
# 31                       Park              Shopping Mall
#
#      7th Most Common Venue      8th Most Common Venue 9th Most Common Venue  \
# 0                 Pharmacy                Pizza Place           Supermarket
# 1                 Pharmacy         Italian Restaurant                 Plaza
# 2       Italian Restaurant                 Boxing Gym             Bookstore
# 3                   Market       Fast Food Restaurant                  Park
# 4        Convenience Store                 Donut Shop        Ice Cream Shop
# 5                Juice Bar             Ice Cream Shop     Mobile Phone Shop
# 6     Fast Food Restaurant              Grocery Store        Breakfast Spot
# 7                     Café              Jewelry Store           Supermarket
# 8           Ice Cream Shop                   Pharmacy           Candy Store
# 9                      Gym                Supermarket                Bakery
# 10                   Hotel       Fast Food Restaurant        Breakfast Spot
# 11          Ice Cream Shop  Middle Eastern Restaurant    Falafel Restaurant
# 12                   Trail               Dessert Shop                  Café
# 13            Perfume Shop                   Pharmacy           Flower Shop
# 14               Gift Shop        Fried Chicken Joint            Food Truck
# 15     Fried Chicken Joint              Shopping Mall                 Trail
# 16              Smoke Shop               Soccer Field                   Bar
# 17              Donut Shop          Mobile Phone Shop        Ice Cream Shop
# 18            Burger Joint             Breakfast Spot     Indian Restaurant
# 19             Pizza Place        Sporting Goods Shop          Soccer Field
# 20                    Park                   Pharmacy           Pizza Place
# 21    Fast Food Restaurant                Art Gallery             Juice Bar
# 22          Breakfast Spot         Falafel Restaurant             Juice Bar
# 23          Ice Cream Shop                  Bookstore        Breakfast Spot
# 24               Juice Bar              Shopping Mall           Supermarket
# 25                  Bakery       Fast Food Restaurant                 Hotel
# 26    Gym / Fitness Center     Furniture / Home Store        Clothing Store
# 27    Fast Food Restaurant                  Bookstore   American Restaurant
# 28  Furniture / Home Store             Clothing Store   Fried Chicken Joint
# 29          Cosmetics Shop             Ice Cream Shop        Breakfast Spot
# 30            Burger Joint       Fast Food Restaurant        Ice Cream Shop
# 31    Fast Food Restaurant                     Market     Convenience Store
#
#        10th Most Common Venue
# 0                        Park
# 1                        Café
# 2           Mobile Phone Shop
# 3                 Pizza Place
# 4                        Bank
# 5                      Market
# 6      Furniture / Home Store
# 7              Cosmetics Shop
# 8         Fried Chicken Joint
# 9          Falafel Restaurant
# 10                 Restaurant
# 11               Optical Shop
# 12             Breakfast Spot
# 13               Burger Joint
# 14               Burger Joint
# 15             Sandwich Place
# 16                Music Venue
# 17                   Pharmacy
# 18                     Bakery
# 19                       Park
# 20                 Restaurant
# 21                  Gift Shop
# 22                     Bakery
# 23  Middle Eastern Restaurant
# 24        Sporting Goods Shop
# 25               Burger Joint
# 26               Cupcake Shop
# 27                Supermarket
# 28                  Pet Store
# 29          Electronics Store
# 30                Pizza Place
# 31         Falafel Restaurant

# %% [markdown]
# ## Let's also look at how neighborhoods come together when we cluster them into 10 means

# %%
kclusters = 10
riyadh_grouped_clustering = riyadh_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=42).fit(riyadh_grouped_clustering)
label = kmeans.labels_.tolist()

# %%
riyadh_merged = riyadh_neighborhoods
riyadh_merged['Cluster Labels'] = label
riyadh_merged = riyadh_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
riyadh_merged.head()
# Out:
#      Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0       Umm Salim  24.633751  46.694103               9
# 1      Al Izdihar  24.780655  46.700005               6
# 2       At Taawun  24.773076  46.681970               1
# 3      Al Jazirah  24.664702  46.778970               9
# 4  As Sulimaniyah  24.698527  46.667436               0
#
#     1st Most Common Venue 2nd Most Common Venue      3rd Most Common Venue  \
# 0             Coffee Shop        Breakfast Spot  Middle Eastern Restaurant
# 1             Coffee Shop            Donut Shop                  Gift Shop
# 2             Coffee Shop          Dessert Shop                       Café
# 3  Furniture / Home Store  Fast Food Restaurant          Electronics Store
# 4             Coffee Shop          Dessert Shop              Jewelry Store
#
#   4th Most Common Venue      5th Most Common Venue 6th Most Common Venue  \
# 0                  Café                       Park         Shopping Mall
# 1           Pizza Place                 Restaurant        Ice Cream Shop
# 2           Pizza Place                 Donut Shop            Restaurant
# 3           Coffee Shop           Department Store                  Park
# 4          Burger Joint  Middle Eastern Restaurant        Clothing Store
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0  Fast Food Restaurant                Market     Convenience Store
# 1              Pharmacy    Italian Restaurant                 Plaza
# 2        Ice Cream Shop             Bookstore        Breakfast Spot
# 3    Italian Restaurant            Boxing Gym             Bookstore
# 4  Fast Food Restaurant           Art Gallery             Juice Bar
#
#       10th Most Common Venue
# 0         Falafel Restaurant
# 1                       Café
# 2  Middle Eastern Restaurant
# 3          Mobile Phone Shop
# 4                  Gift Shop

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
markers_colors = []
for lat, lon, poi, cluster in zip(riyadh_merged['Latitude'], riyadh_merged['Longitude'], riyadh_merged['Neighborhood'], riyadh_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Test our application

# %% [markdown]
# ### What is the best neighborhood for a pizza place?

# %%
getBestBusinessNeighborhood('Pizza Place')
# Out:
# 'Al Jazirah'

# %% [markdown]
# ### What is the best neighborhood for a Coffee Shop?

# %%
getBestBusinessNeighborhood('Coffee Shop')
# Out:
# 'An Nazim'

# %% [markdown]
# ### What is the best neighborhood for a Donut Shop?

# %%
getBestBusinessNeighborhood('Donut Shop')
# Out:
# 'Al Jazirah'

# %% [markdown]
# ### What is the best neighborhood for a Fast Food Restaurant?

# %%
getBestBusinessNeighborhood('Fast Food Restaurant')
# Out:
# 'Al Mursalat'

# %% [markdown]
# ### What is the best neighborhood for an Electronics Store?

# %%
getBestBusinessNeighborhood('Electronics Store')
# Out:
# 'Al Falah'
